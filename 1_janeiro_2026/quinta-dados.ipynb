# %% [markdown]
# # Atividade de estudo (para 02/02/2026)
#
# Siga os passos a seguir para responder quatro (4) questões sobre a base de dados e para propor uma (1) adicional, do seu interesse.
#
# ## 1. Pacotes necessários

# %%
# Instala e carrega pacotes
install.packages('googlesheets4')
library(googlesheets4)
# Out:
# Installing package into ‘C:/Users/msn/AppData/Local/R/win-library/4.5’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/bin/windows/contrib/4.5/googlesheets4_1.1.2.zip'
# Content type 'application/zip' length 524864 bytes (512 KB)
# downloaded 512 KB
# package ‘googlesheets4’ successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\msn\AppData\Local\Temp\Rtmp6brBLE\downloaded_packages
# Warning message:
# package ‘googlesheets4’ was built under R version 4.5.2

# %% [markdown]
# ## 2.Base de dados
#
# O código abaixo carrega a planilha do Google resultante do preenchimento do formulário. As planilhas precisam estar com direitos de leitura para *qualquer pessoa*, caso contrário o código R não conseguirá recuperar os dados.

# %%
# desabilita autenticação
gs4_deauth()

# Planilha do Google dos Forms
dados <- read_sheet('https://docs.google.com/spreadsheets/d/18hjusu_1w_smo5RYcEZ7pH8wf01ta2ZIG9ru6Lr2zU4/edit?usp=sharing')
# Out:
# ✔ Reading from "Coleta de dados exemplo (respostas)".
# ✔ Range Respostas ao formulário 1.

# %% [markdown]
# ## 3. Perguntas
#
# Analise a base de dados e, utilizando os exemplos de funções da [quarta](./quarta.ipynb) e [quinta](./quinta.ipynb), escreva células de código que possam investigar as seguintes questões:
#
# 1. Quantos municípios diferentes existem na base?
# 2. Qual é a média e mediana das idades e alturas?
# 3. Qual é a escolaridade das dez pessoas mais velhas?
# 4. Em qual munício residem as pessoas mais baixas e qual é a altura média delas?
# 5. Elabore a sua pergunta!

# %%
# vamos nessa!
